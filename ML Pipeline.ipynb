# %%
# %pip install zenml[server]
# !zenml integration install sklearn -y
# Out:
# ...
#
#   Obtaining dependency information for zenml[server] from https://files.pythonhosted.org/packages/7f/42/94b8fb163977f8b7104b236055e692a756f4ed5ae170261497f640749cf3/zenml-0.71.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for alembic<1.9.0,>=1.8.1 from https://files.pythonhosted.org/packages/b3/c8/69600a8138a56794713ecdb8b75b14fbe32a410bc444683f27dbab93c0ca/alembic-1.8.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for bcrypt==4.0.1 from https://files.pythonhosted.org/packages/46/81/d8c22cd7e5e1c6a7d48e41a1d1d46c92f17dae70a54d9814f746e6027dec/bcrypt-4.0.1-cp36-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for distro<2.0.0,>=1.6.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
# ...

# %%
# !rm -rf .zen
# !zenml init
# Out:
# ⠋ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠙ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠹ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠸ Initializing ZenML repository at e:\Projects\MLOps.
# Initializing the ZenML global configuration version to 0.71.0
#
# ⠼ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠴ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠧ Initializing ZenML repository at e:\Projects\MLOps.
# Creating database tables
#
# ⠇ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠏ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠋ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠼ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠴ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠦ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠇ Initializing ZenML repository at e:\Projects\MLOps.
#
# ⠏ Initializing ZenML repository at e:\Projects\MLOps.
#
# ...
